# %% [markdown]
# <a href="https://colab.research.google.com/github/mzaoualim/Business_Proposals/blob/main/json_arrays_manipulation_project/steps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_json('/content/Reviews-Array.txt')

# %%
df = pd.DataFrame.from_dict(data=data.iloc[:, 0].to_dict(), orient='index')
df
# Out:
#                                          review_text  review_rating  \
# 0  There are plenty of cleaning companies out the...              1
# 1                                   They're the best              5
# 2  Poor management skills and they treat employee...              1
# 3                                                                 2
#
#                                          review_link  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...
# 1  https://www.google.com/maps/reviews/data=!4m8!...
# 2  https://www.google.com/maps/reviews/data=!4m8!...
# 3  https://www.google.com/maps/reviews/data=!4m8!...
#
#                               review_id  review_datetime_utc  \
# 0  ChdDSUhNMG9nS0VJQ0FnSURsMHZySTVnRRAB  12/01/2023 04:49:31
# 1   ChZDSUhNMG9nS0VJQ0FnSUQ1eHFhV0hnEAE  10/23/2023 21:05:38
# 2  ChdDSUhNMG9nS0VJQ0FnSURacmJPendBRRAB  10/06/2023 13:35:05
# 3  ChdDSUhNMG9nS0VJQ0FnSUNwdjhHbTFRRRAB  08/13/2023 15:05:22
#
#        author_title                                        author_link  \
# 0   Danielle Walker  https://www.google.com/maps/contrib/1094449828...
# 1  Christopher Noel  https://www.google.com/maps/contrib/1035768288...
# 2     chris perkins  https://www.google.com/maps/contrib/1001487806...
# 3       julie meese  https://www.google.com/maps/contrib/1181139174...
#
#                                         author_image
# 0  https://lh3.googleusercontent.com/a/ACg8ocL51O...
# 1  https://lh3.googleusercontent.com/a-/ALV-UjXPA...
# 2  https://lh3.googleusercontent.com/a-/ALV-UjVJR...
# 3  https://lh3.googleusercontent.com/a-/ALV-UjVrq...

# %%
df.columns
# Out:
# Index(['review_text', 'review_rating', 'review_link', 'review_id',
#        'review_datetime_utc', 'author_title', 'author_link', 'author_image'],
#       dtype='object')

# %%
df[['review_link', 'review_id',
       'review_datetime_utc', 'author_title']]
# Out:
#                                          review_link  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...
# 1  https://www.google.com/maps/reviews/data=!4m8!...
# 2  https://www.google.com/maps/reviews/data=!4m8!...
# 3  https://www.google.com/maps/reviews/data=!4m8!...
#
#                               review_id  review_datetime_utc      author_title
# 0  ChdDSUhNMG9nS0VJQ0FnSURsMHZySTVnRRAB  12/01/2023 04:49:31   Danielle Walker
# 1   ChZDSUhNMG9nS0VJQ0FnSUQ1eHFhV0hnEAE  10/23/2023 21:05:38  Christopher Noel
# 2  ChdDSUhNMG9nS0VJQ0FnSURacmJPendBRRAB  10/06/2023 13:35:05     chris perkins
# 3  ChdDSUhNMG9nS0VJQ0FnSUNwdjhHbTFRRRAB  08/13/2023 15:05:22       julie meese

# %%
# streamlit app demonstration
import streamlit as st
import pandas as pd

# loading data
data = pd.read_csv('json_arrays_manipulation_project/demo_app/Reviews-Array.txt')
# data manipulation
df = pd.DataFrame.from_dict(data=data.iloc[:, 0].to_dict(), orient='index')
cols = df.columns


def main():
  # App Title
  st.markdown("<h1 style='text-align: center;'> Script Demo </h1>", unsafe_allow_html=True)
  st.write('---')

  # raw data preview
  st.markdown("<h2 style='text-align: center;'> Raw Data </h2>", unsafe_allow_html=True)
  st.write('json_arrays_manipulation_project/demo_app/Reviews-Array.txt')
  st.write('---')

  # select cols
  col_select = st.multiselect('Select desired columns', cols)

  # display selected data
  submit = st.button('Get filtered Data', use_container_width=True)
  if submit:
    st.dataframe(data[col_select], use_container_width=True)

    # prepare to download filtered data
    csv = data[col_select].to_csv()
    st.download_button(
          label="Download filtered data",
          data=csv,
          file_name='filered.csv',
          mime='text/csv',
          use_container_width=True
        )
  st.write('---')


if __name__ == '__main__':
  main()
